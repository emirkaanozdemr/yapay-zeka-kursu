# %% [raw]
# 1-Entanglement - Dolaniklik
# 2-Superposition - Ust uste binme ilkesi
# 3-Teleportation Isinlanma
# 4-Quantum Tunneling
# 5-Probability - Olasilik

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#pip install qiskit

# %%
#pip install qiskit-ibmq-provider

# %%
#pip install pylatexenc

# %%
#pip install qiskit-aer

# %%
from qiskit import IBMQ

# %%
IBMQ.save_account('296b0ff6ea5951a084c56e77f7752a8a3f6f41d7984b06ed84e6024c9c706a9ea5d51ef739bce08c66b5e1c173f9720ffd1a65d8dce18a8109d97523a22cd0bb')
# Out:
# configrc.store_credentials:WARNING:2024-05-04 00:36:18,328: Credentials already present. Set overwrite=True to overwrite.

# %%
from qiskit import *

# %%
qr=QuantumRegister(2)
cr=ClassicalRegister(2)

# %%
circuit=QuantumCircuit(qr,cr)

# %%
#Hadamart Gate QUantum dolaniklik

# %%
circuit.h(qr[0])

# %%
circuit.draw(output='mpl')

# %%
#CNOT gate controlled X Gate

# %%
circuit.cx(qr[0],qr[1])

# %%
circuit.measure(qr,cr)

# %%
circuit.draw(output='mpl')

# %%
simulator=Aer.get_backend('qasm_simulator')

# %%
result=execute(circuit,backend=simulator).result()

# %%
from qiskit.tools.visualization import plot_histogram

# %%
plot_histogram(result.get_counts())

# %%
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2024-05-04 00:43:59,417: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider=IBMQ.get_provider('ibm-q')

# %%
qcomp=provider.get_backend('ibm_kyoto')

# %%
job=execute(circuit,backend=qcomp)

# %%
from qiskit.tools.monitor import job_monitor

# %%
result=job.result()

# %%
plot_histogram(result.get_counts(circuit))
